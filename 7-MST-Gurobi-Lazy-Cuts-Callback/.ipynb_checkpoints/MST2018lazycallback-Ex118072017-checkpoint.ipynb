# %% [markdown]
# #  Minimum Spanning Tree Problem
#
# ## Gurobi Lazy cuts callback

# %%
import networkx as nx
import gurobipy as gb
from itertools import combinations, chain
#import pygraphviz as pygv
import os
from IPython.display import SVG, display

# %%
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

#
# Drawing 
# functions
#

def DrawInitialGraph():
    global DrawG
    DrawG = pygv.AGraph(undirected='true', strict='true', splines='true')


    for i in G.nodes():
        pos = str(G.node[i]['x'] * args.scale) + ',' + str((G.node[i]['y'])* args.scale)
        DrawG.add_node (i, shape='circle', pos=pos, width=0.1, fontsize=9)
    
    DrawG.layout(prog='neato', args='-n')
    DrawG.draw (path=str(basename) + '.svg', format='svg')
    

def DrawSol (x):
    for i,j in G.edges():
        lab = x[i,j].x
        G[i][j]['capacity'] = x[i,j].x
        if x[i,j].x > 0.00001:
            if x[i,j].x > 0.999999:
                DrawG.add_edge(i, j, color='black', label=lab, fontsize=9)
            else:
                DrawG.add_edge(i, j, color='red', label=lab)
    path=str(basename)+'_sol.svg'
    DrawG.draw (path=path, format='svg')
    DrawG.delete_edges_from(DrawG.edges())

# %%
class args:
    filename = None
    scale = 40

# %% [markdown]
# ### Decision variables:
#
# $$
# x_{ij} = \begin{cases} 1 \text{ if edge } e=\{i,j\} \text{ is selected} \\
# 0 \text{ otherwise.}\end{cases}
# $$
#
# ### Formulation
#
# $$
# \min \sum_{e=\{i,j\} \in E} c_{ij} x_{ij} \\
# \sum_{e=\{i,j\} \in E} x_{ij} = |V| - 1 \\
# \sum_{e=\{i,j\} \in E(S)} x_{ij} \le |S| - 1, \;\; \forall S \subset V, 2 < |S| \le |V| - 1  \\
# x \le 1 \\
# x \ge 0
# $$

# %% [markdown]
# ## Gurobi callbacks

# %%
args.filename = "graph18072017.gml"
args.scale = 40

basename = os.path.splitext(args.filename)[0]
G = nx.read_graphml (args.filename, node_type=int)

print ("G has", G.number_of_nodes(), "nodes and", G.number_of_edges(), "edges")
# Out:
# G has 25 nodes and 300 edges

# %%
mst = gb.Model()

# Decision Variables

x = mst.addVars(G.edges(),\
                obj=[G[u][v]['cost'] for u,v in G.edges()],\
                ub = 1.0,\
                vtype=gb.GRB.BINARY, name='x')

# Cardinality constraint

mst.addConstr(x.sum() == G.number_of_nodes() - 1, 'Cardinality')

mst.update()

mst.write('mst.lp')

# %% [markdown]
# ## Data needed to the callback
#
# Our callback needs:
#    1. The graph $G$
#    2. The variables $x$
#    3. The separation routine
#    4. The number of SECs generated so far
#
# The above data are added to the ``mst`` Model. Note the ``_`` before the data name

# %%
mst._graph = G
mst._vars = x
mst._nSEC = 0



import math
import itertools

def SECcallback (model, where):

        
    if where == gb.GRB.Callback.MIPSOL:
        
        x = model._vars
        xrel = model.cbGetSolution(x)
        G = model._graph
        
        #
        # Make a graph working copy
        # Not efficient !!!
        #
        
        solG = nx.Graph([(u,v) for (u,v) in G.edges() \
                         if math.isclose(xrel[u,v], 1.0, abs_tol=1E-3)])

        #
        # Check if solG is connected
        #
        
        for cc in nx.connected_components(solG):
            if G.subgraph(cc).number_of_edges() > len(cc) - 1 and len(cc) > 2:
                seclhs = gb.quicksum(x[u,v] if (u,v) in x else x[v,u] \
                                 for u,v in itertools.combinations(cc, 2))
            
                model.cbLazy(seclhs <= len(cc) - 1)
                

mst.reset()
mst.Params.lazyConstraints = 1
mst.optimize(SECcallback)
# Out:
# Parameter lazyConstraints unchanged
#    Value: 1  Min: 0  Max: 1  Default: 0
# Optimize a model with 1 rows, 300 columns and 300 nonzeros
# Variable types: 0 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 8e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+01]
# Presolve time: 0.00s
# Presolved: 1 rows, 300 columns, 300 nonzeros
# Variable types: 0 continuous, 300 integer (300 binary)
#
# Root relaxation: objective 1.478700e+04, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    19054.000000 19054.0000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 9
#
# Explored 0 nodes (24 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 19054
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.905400000000e+04, best bound 1.905400000000e+04, gap 0.0000%

# %%
type(mst.objVal)
# Out:
# float

# %%
DrawInitialGraph()
DrawSol(x)
display(SVG(filename=basename+'_sol.svg'))

# %%
x
# Out:
# {(1, 2): <gurobi.Var x[1,2] (value -0.0)>,
#  (1, 3): <gurobi.Var x[1,3] (value 1.0)>,
#  (1, 4): <gurobi.Var x[1,4] (value -0.0)>,
#  (1, 5): <gurobi.Var x[1,5] (value -0.0)>,
#  (1, 6): <gurobi.Var x[1,6] (value -0.0)>,
#  (1, 7): <gurobi.Var x[1,7] (value -0.0)>,
#  (1, 8): <gurobi.Var x[1,8] (value 1.0)>,
#  (1, 9): <gurobi.Var x[1,9] (value -0.0)>,
#  (1, 10): <gurobi.Var x[1,10] (value -0.0)>,
#  (1, 11): <gurobi.Var x[1,11] (value -0.0)>,
#  (1, 12): <gurobi.Var x[1,12] (value -0.0)>,
#  (1, 13): <gurobi.Var x[1,13] (value -0.0)>,
#  (1, 14): <gurobi.Var x[1,14] (value 1.0)>,
#  (1, 15): <gurobi.Var x[1,15] (value -0.0)>,
#  (1, 16): <gurobi.Var x[1,16] (value -0.0)>,
#  (1, 17): <gurobi.Var x[1,17] (value -0.0)>,
#  (1, 18): <gurobi.Var x[1,18] (value -0.0)>,
#  (1, 19): <gurobi.Var x[1,19] (value -0.0)>,
#  (1, 20): <gurobi.Var x[1,20] (value -0.0)>,
#  (1, 21): <gurobi.Var x[1,21] (value -0.0)>,
#  (1, 22): <gurobi.Var x[1,22] (value -0.0)>,
#  (1, 23): <gurobi.Var x[1,23] (value -0.0)>,
#  (1, 24): <gurobi.Var x[1,24] (value -0.0)>,
#  (1, 25): <gurobi.Var x[1,25] (value -0.0)>,
#  (2, 3): <gurobi.Var x[2,3] (value -0.0)>,
#  (2, 4): <gurobi.Var x[2,4] (value -0.0)>,
#  (2, 5): <gurobi.Var x[2,5] (value -0.0)>,
#  (2, 6): <gurobi.Var x[2,6] (value -0.0)>,
#  (2, 7): <gurobi.Var x[2,7] (value 1.0)>,
#  (2, 8): <gurobi.Var x[2,8] (value -0.0)>,
#  (2, 9): <gurobi.Var x[2,9] (value -0.0)>,
#  (2, 10): <gurobi.Var x[2,10] (value -0.0)>,
#  (2, 11): <gurobi.Var x[2,11] (value -0.0)>,
#  (2, 12): <gurobi.Var x[2,12] (value -0.0)>,
#  (2, 13): <gurobi.Var x[2,13] (value -0.0)>,
#  (2, 14): <gurobi.Var x[2,14] (value -0.0)>,
#  (2, 15): <gurobi.Var x[2,15] (value -0.0)>,
#  (2, 16): <gurobi.Var x[2,16] (value -0.0)>,
#  (2, 17): <gurobi.Var x[2,17] (value -0.0)>,
#  (2, 18): <gurobi.Var x[2,18] (value -0.0)>,
#  (2, 19): <gurobi.Var x[2,19] (value -0.0)>,
#  (2, 20): <gurobi.Var x[2,20] (value -0.0)>,
#  (2, 21): <gurobi.Var x[2,21] (value -0.0)>,
#  (2, 22): <gurobi.Var x[2,22] (value -0.0)>,
#  (2, 23): <gurobi.Var x[2,23] (value -0.0)>,
#  (2, 24): <gurobi.Var x[2,24] (value 0.0)>,
#  (2, 25): <gurobi.Var x[2,25] (value -0.0)>,
#  (3, 4): <gurobi.Var x[3,4] (value -0.0)>,
#  (3, 5): <gurobi.Var x[3,5] (value -0.0)>,
#  (3, 6): <gurobi.Var x[3,6] (value -0.0)>,
#  (3, 7): <gurobi.Var x[3,7] (value -0.0)>,
#  (3, 8): <gurobi.Var x[3,8] (value 0.0)>,
#  (3, 9): <gurobi.Var x[3,9] (value -0.0)>,
#  (3, 10): <gurobi.Var x[3,10] (value -0.0)>,
#  (3, 11): <gurobi.Var x[3,11] (value -0.0)>,
#  (3, 12): <gurobi.Var x[3,12] (value -0.0)>,
#  (3, 13): <gurobi.Var x[3,13] (value 1.0)>,
#  (3, 14): <gurobi.Var x[3,14] (value -0.0)>,
#  (3, 15): <gurobi.Var x[3,15] (value -0.0)>,
#  (3, 16): <gurobi.Var x[3,16] (value -0.0)>,
#  (3, 17): <gurobi.Var x[3,17] (value -0.0)>,
#  (3, 18): <gurobi.Var x[3,18] (value -0.0)>,
#  (3, 19): <gurobi.Var x[3,19] (value -0.0)>,
#  (3, 20): <gurobi.Var x[3,20] (value -0.0)>,
#  (3, 21): <gurobi.Var x[3,21] (value -0.0)>,
#  (3, 22): <gurobi.Var x[3,22] (value -0.0)>,
#  (3, 23): <gurobi.Var x[3,23] (value -0.0)>,
#  (3, 24): <gurobi.Var x[3,24] (value -0.0)>,
#  (3, 25): <gurobi.Var x[3,25] (value -0.0)>,
#  (4, 5): <gurobi.Var x[4,5] (value -0.0)>,
#  (4, 6): <gurobi.Var x[4,6] (value -0.0)>,
#  (4, 7): <gurobi.Var x[4,7] (value -0.0)>,
#  (4, 8): <gurobi.Var x[4,8] (value -0.0)>,
#  (4, 9): <gurobi.Var x[4,9] (value -0.0)>,
#  (4, 10): <gurobi.Var x[4,10] (value -0.0)>,
#  (4, 11): <gurobi.Var x[4,11] (value -0.0)>,
#  (4, 12): <gurobi.Var x[4,12] (value -0.0)>,
#  (4, 13): <gurobi.Var x[4,13] (value -0.0)>,
#  (4, 14): <gurobi.Var x[4,14] (value -0.0)>,
#  (4, 15): <gurobi.Var x[4,15] (value -0.0)>,
#  (4, 16): <gurobi.Var x[4,16] (value -0.0)>,
#  (4, 17): <gurobi.Var x[4,17] (value 1.0)>,
#  (4, 18): <gurobi.Var x[4,18] (value -0.0)>,
#  (4, 19): <gurobi.Var x[4,19] (value -0.0)>,
#  (4, 20): <gurobi.Var x[4,20] (value -0.0)>,
#  (4, 21): <gurobi.Var x[4,21] (value -0.0)>,
#  (4, 22): <gurobi.Var x[4,22] (value 0.0)>,
#  (4, 23): <gurobi.Var x[4,23] (value 1.0)>,
#  (4, 24): <gurobi.Var x[4,24] (value -0.0)>,
#  (4, 25): <gurobi.Var x[4,25] (value -0.0)>,
#  (5, 6): <gurobi.Var x[5,6] (value -0.0)>,
#  (5, 7): <gurobi.Var x[5,7] (value -0.0)>,
#  (5, 8): <gurobi.Var x[5,8] (value -0.0)>,
#  (5, 9): <gurobi.Var x[5,9] (value -0.0)>,
#  (5, 10): <gurobi.Var x[5,10] (value -0.0)>,
#  (5, 11): <gurobi.Var x[5,11] (value -0.0)>,
#  (5, 12): <gurobi.Var x[5,12] (value -0.0)>,
#  (5, 13): <gurobi.Var x[5,13] (value -0.0)>,
#  (5, 14): <gurobi.Var x[5,14] (value -0.0)>,
#  (5, 15): <gurobi.Var x[5,15] (value -0.0)>,
#  (5, 16): <gurobi.Var x[5,16] (value -0.0)>,
#  (5, 17): <gurobi.Var x[5,17] (value -0.0)>,
#  (5, 18): <gurobi.Var x[5,18] (value -0.0)>,
#  (5, 19): <gurobi.Var x[5,19] (value -0.0)>,
#  (5, 20): <gurobi.Var x[5,20] (value -0.0)>,
#  (5, 21): <gurobi.Var x[5,21] (value -0.0)>,
#  (5, 22): <gurobi.Var x[5,22] (value 1.0)>,
#  (5, 23): <gurobi.Var x[5,23] (value -0.0)>,
#  (5, 24): <gurobi.Var x[5,24] (value -0.0)>,
#  (5, 25): <gurobi.Var x[5,25] (value -0.0)>,
#  (6, 7): <gurobi.Var x[6,7] (value -0.0)>,
#  (6, 8): <gurobi.Var x[6,8] (value -0.0)>,
#  (6, 9): <gurobi.Var x[6,9] (value -0.0)>,
#  (6, 10): <gurobi.Var x[6,10] (value 1.000000000000001)>,
#  (6, 11): <gurobi.Var x[6,11] (value -0.0)>,
#  (6, 12): <gurobi.Var x[6,12] (value -0.0)>,
#  (6, 13): <gurobi.Var x[6,13] (value -0.0)>,
#  (6, 14): <gurobi.Var x[6,14] (value -0.0)>,
#  (6, 15): <gurobi.Var x[6,15] (value 1.0)>,
#  (6, 16): <gurobi.Var x[6,16] (value -0.0)>,
#  (6, 17): <gurobi.Var x[6,17] (value -0.0)>,
#  (6, 18): <gurobi.Var x[6,18] (value -0.0)>,
#  (6, 19): <gurobi.Var x[6,19] (value -0.0)>,
#  (6, 20): <gurobi.Var x[6,20] (value -0.0)>,
#  (6, 21): <gurobi.Var x[6,21] (value 1.0)>,
#  (6, 22): <gurobi.Var x[6,22] (value -0.0)>,
#  (6, 23): <gurobi.Var x[6,23] (value -0.0)>,
#  (6, 24): <gurobi.Var x[6,24] (value -0.0)>,
#  (6, 25): <gurobi.Var x[6,25] (value -0.0)>,
#  (7, 8): <gurobi.Var x[7,8] (value -0.0)>,
#  (7, 9): <gurobi.Var x[7,9] (value 1.0)>,
#  (7, 10): <gurobi.Var x[7,10] (value -0.0)>,
#  (7, 11): <gurobi.Var x[7,11] (value -0.0)>,
#  (7, 12): <gurobi.Var x[7,12] (value -0.0)>,
#  (7, 13): <gurobi.Var x[7,13] (value -0.0)>,
#  (7, 14): <gurobi.Var x[7,14] (value -0.0)>,
#  (7, 15): <gurobi.Var x[7,15] (value -0.0)>,
#  (7, 16): <gurobi.Var x[7,16] (value -0.0)>,
#  (7, 17): <gurobi.Var x[7,17] (value -0.0)>,
#  (7, 18): <gurobi.Var x[7,18] (value -0.0)>,
#  (7, 19): <gurobi.Var x[7,19] (value -0.0)>,
#  (7, 20): <gurobi.Var x[7,20] (value -0.0)>,
#  (7, 21): <gurobi.Var x[7,21] (value -0.0)>,
#  (7, 22): <gurobi.Var x[7,22] (value -0.0)>,
#  (7, 23): <gurobi.Var x[7,23] (value -0.0)>,
#  (7, 24): <gurobi.Var x[7,24] (value 1.0)>,
#  (7, 25): <gurobi.Var x[7,25] (value -0.0)>,
#  (8, 9): <gurobi.Var x[8,9] (value -0.0)>,
#  (8, 10): <gurobi.Var x[8,10] (value -0.0)>,
#  (8, 11): <gurobi.Var x[8,11] (value -0.0)>,
#  (8, 12): <gurobi.Var x[8,12] (value -0.0)>,
#  (8, 13): <gurobi.Var x[8,13] (value -0.0)>,
#  (8, 14): <gurobi.Var x[8,14] (value -0.0)>,
#  (8, 15): <gurobi.Var x[8,15] (value -0.0)>,
#  (8, 16): <gurobi.Var x[8,16] (value -0.0)>,
#  (8, 17): <gurobi.Var x[8,17] (value -0.0)>,
#  (8, 18): <gurobi.Var x[8,18] (value -0.0)>,
#  (8, 19): <gurobi.Var x[8,19] (value -0.0)>,
#  (8, 20): <gurobi.Var x[8,20] (value -0.0)>,
#  (8, 21): <gurobi.Var x[8,21] (value 1.0)>,
#  (8, 22): <gurobi.Var x[8,22] (value -0.0)>,
#  (8, 23): <gurobi.Var x[8,23] (value -0.0)>,
#  (8, 24): <gurobi.Var x[8,24] (value -0.0)>,
#  (8, 25): <gurobi.Var x[8,25] (value -0.0)>,
#  (9, 10): <gurobi.Var x[9,10] (value -0.0)>,
#  (9, 11): <gurobi.Var x[9,11] (value -0.0)>,
#  (9, 12): <gurobi.Var x[9,12] (value -0.0)>,
#  (9, 13): <gurobi.Var x[9,13] (value 1.0)>,
#  (9, 14): <gurobi.Var x[9,14] (value -0.0)>,
#  (9, 15): <gurobi.Var x[9,15] (value -0.0)>,
#  (9, 16): <gurobi.Var x[9,16] (value -0.0)>,
#  (9, 17): <gurobi.Var x[9,17] (value -0.0)>,
#  (9, 18): <gurobi.Var x[9,18] (value -0.0)>,
#  (9, 19): <gurobi.Var x[9,19] (value -0.0)>,
#  (9, 20): <gurobi.Var x[9,20] (value -0.0)>,
#  (9, 21): <gurobi.Var x[9,21] (value -0.0)>,
#  (9, 22): <gurobi.Var x[9,22] (value -0.0)>,
#  (9, 23): <gurobi.Var x[9,23] (value -0.0)>,
#  (9, 24): <gurobi.Var x[9,24] (value 0.0)>,
#  (9, 25): <gurobi.Var x[9,25] (value -0.0)>,
#  (10, 11): <gurobi.Var x[10,11] (value -0.0)>,
#  (10, 12): <gurobi.Var x[10,12] (value -0.0)>,
#  (10, 13): <gurobi.Var x[10,13] (value -0.0)>,
#  (10, 14): <gurobi.Var x[10,14] (value -0.0)>,
#  (10, 15): <gurobi.Var x[10,15] (value -0.0)>,
#  (10, 16): <gurobi.Var x[10,16] (value -0.0)>,
#  (10, 17): <gurobi.Var x[10,17] (value -0.0)>,
#  (10, 18): <gurobi.Var x[10,18] (value -0.0)>,
#  (10, 19): <gurobi.Var x[10,19] (value -0.0)>,
#  (10, 20): <gurobi.Var x[10,20] (value -0.0)>,
#  (10, 21): <gurobi.Var x[10,21] (value -0.0)>,
#  (10, 22): <gurobi.Var x[10,22] (value -0.0)>,
#  (10, 23): <gurobi.Var x[10,23] (value -0.0)>,
#  (10, 24): <gurobi.Var x[10,24] (value -0.0)>,
#  (10, 25): <gurobi.Var x[10,25] (value -0.0)>,
#  (11, 12): <gurobi.Var x[11,12] (value -0.0)>,
#  (11, 13): <gurobi.Var x[11,13] (value -0.0)>,
#  (11, 14): <gurobi.Var x[11,14] (value -0.0)>,
#  (11, 15): <gurobi.Var x[11,15] (value -0.0)>,
#  (11, 16): <gurobi.Var x[11,16] (value 0.0)>,
#  (11, 17): <gurobi.Var x[11,17] (value -0.0)>,
#  (11, 18): <gurobi.Var x[11,18] (value -0.0)>,
#  (11, 19): <gurobi.Var x[11,19] (value -0.0)>,
#  (11, 20): <gurobi.Var x[11,20] (value -0.0)>,
#  (11, 21): <gurobi.Var x[11,21] (value -0.0)>,
#  (11, 22): <gurobi.Var x[11,22] (value 1.0)>,
#  (11, 23): <gurobi.Var x[11,23] (value -0.0)>,
#  (11, 24): <gurobi.Var x[11,24] (value -0.0)>,
#  (11, 25): <gurobi.Var x[11,25] (value 1.0)>,
#  (12, 13): <gurobi.Var x[12,13] (value -0.0)>,
#  (12, 14): <gurobi.Var x[12,14] (value 1.0)>,
#  (12, 15): <gurobi.Var x[12,15] (value -0.0)>,
#  (12, 16): <gurobi.Var x[12,16] (value -0.0)>,
#  (12, 17): <gurobi.Var x[12,17] (value -0.0)>,
#  (12, 18): <gurobi.Var x[12,18] (value -0.0)>,
#  (12, 19): <gurobi.Var x[12,19] (value -0.0)>,
#  (12, 20): <gurobi.Var x[12,20] (value -0.0)>,
#  (12, 21): <gurobi.Var x[12,21] (value -0.0)>,
#  (12, 22): <gurobi.Var x[12,22] (value -0.0)>,
#  (12, 23): <gurobi.Var x[12,23] (value -0.0)>,
#  (12, 24): <gurobi.Var x[12,24] (value -0.0)>,
#  (12, 25): <gurobi.Var x[12,25] (value -0.0)>,
#  (13, 14): <gurobi.Var x[13,14] (value -0.0)>,
#  (13, 15): <gurobi.Var x[13,15] (value -0.0)>,
#  (13, 16): <gurobi.Var x[13,16] (value -0.0)>,
#  (13, 17): <gurobi.Var x[13,17] (value -0.0)>,
#  (13, 18): <gurobi.Var x[13,18] (value -0.0)>,
#  (13, 19): <gurobi.Var x[13,19] (value 1.0)>,
#  (13, 20): <gurobi.Var x[13,20] (value -0.0)>,
#  (13, 21): <gurobi.Var x[13,21] (value -0.0)>,
#  (13, 22): <gurobi.Var x[13,22] (value -0.0)>,
#  (13, 23): <gurobi.Var x[13,23] (value -0.0)>,
#  (13, 24): <gurobi.Var x[13,24] (value -0.0)>,
#  (13, 25): <gurobi.Var x[13,25] (value -0.0)>,
#  (14, 15): <gurobi.Var x[14,15] (value -0.0)>,
#  (14, 16): <gurobi.Var x[14,16] (value -0.0)>,
#  (14, 17): <gurobi.Var x[14,17] (value -0.0)>,
#  (14, 18): <gurobi.Var x[14,18] (value -0.0)>,
#  (14, 19): <gurobi.Var x[14,19] (value -0.0)>,
#  (14, 20): <gurobi.Var x[14,20] (value -0.0)>,
#  (14, 21): <gurobi.Var x[14,21] (value -0.0)>,
#  (14, 22): <gurobi.Var x[14,22] (value -0.0)>,
#  (14, 23): <gurobi.Var x[14,23] (value -0.0)>,
#  (14, 24): <gurobi.Var x[14,24] (value -0.0)>,
#  (14, 25): <gurobi.Var x[14,25] (value -0.0)>,
#  (15, 16): <gurobi.Var x[15,16] (value -0.0)>,
#  (15, 17): <gurobi.Var x[15,17] (value -0.0)>,
#  (15, 18): <gurobi.Var x[15,18] (value -0.0)>,
#  (15, 19): <gurobi.Var x[15,19] (value -0.0)>,
#  (15, 20): <gurobi.Var x[15,20] (value -0.0)>,
#  (15, 21): <gurobi.Var x[15,21] (value -0.0)>,
#  (15, 22): <gurobi.Var x[15,22] (value -0.0)>,
#  (15, 23): <gurobi.Var x[15,23] (value 1.0)>,
#  (15, 24): <gurobi.Var x[15,24] (value -0.0)>,
#  (15, 25): <gurobi.Var x[15,25] (value -0.0)>,
#  (16, 17): <gurobi.Var x[16,17] (value -0.0)>,
#  (16, 18): <gurobi.Var x[16,18] (value -0.0)>,
#  (16, 19): <gurobi.Var x[16,19] (value -0.0)>,
#  (16, 20): <gurobi.Var x[16,20] (value 0.0)>,
#  (16, 21): <gurobi.Var x[16,21] (value -0.0)>,
#  (16, 22): <gurobi.Var x[16,22] (value -0.0)>,
#  (16, 23): <gurobi.Var x[16,23] (value -0.0)>,
#  (16, 24): <gurobi.Var x[16,24] (value -0.0)>,
#  (16, 25): <gurobi.Var x[16,25] (value 1.0)>,
#  (17, 18): <gurobi.Var x[17,18] (value -0.0)>,
#  (17, 19): <gurobi.Var x[17,19] (value -0.0)>,
#  (17, 20): <gurobi.Var x[17,20] (value -0.0)>,
#  (17, 21): <gurobi.Var x[17,21] (value -0.0)>,
#  (17, 22): <gurobi.Var x[17,22] (value -0.0)>,
#  (17, 23): <gurobi.Var x[17,23] (value 0.0)>,
#  (17, 24): <gurobi.Var x[17,24] (value -0.0)>,
#  (17, 25): <gurobi.Var x[17,25] (value -0.0)>,
#  (18, 19): <gurobi.Var x[18,19] (value -0.0)>,
#  (18, 20): <gurobi.Var x[18,20] (value 0.9999999999999989)>,
#  (18, 21): <gurobi.Var x[18,21] (value -0.0)>,
#  (18, 22): <gurobi.Var x[18,22] (value 1.0)>,
#  (18, 23): <gurobi.Var x[18,23] (value 1.0)>,
#  (18, 24): <gurobi.Var x[18,24] (value -0.0)>,
#  (18, 25): <gurobi.Var x[18,25] (value -0.0)>,
#  (19, 20): <gurobi.Var x[19,20] (value -0.0)>,
#  (19, 21): <gurobi.Var x[19,21] (value -0.0)>,
#  (19, 22): <gurobi.Var x[19,22] (value -0.0)>,
#  (19, 23): <gurobi.Var x[19,23] (value -0.0)>,
#  (19, 24): <gurobi.Var x[19,24] (value -0.0)>,
#  (19, 25): <gurobi.Var x[19,25] (value -0.0)>,
#  (20, 21): <gurobi.Var x[20,21] (value -0.0)>,
#  (20, 22): <gurobi.Var x[20,22] (value -0.0)>,
#  (20, 23): <gurobi.Var x[20,23] (value -0.0)>,
#  (20, 24): <gurobi.Var x[20,24] (value -0.0)>,
#  (20, 25): <gurobi.Var x[20,25] (value -0.0)>,
#  (21, 22): <gurobi.Var x[21,22] (value -0.0)>,
#  (21, 23): <gurobi.Var x[21,23] (value -0.0)>,
#  (21, 24): <gurobi.Var x[21,24] (value -0.0)>,
#  (21, 25): <gurobi.Var x[21,25] (value -0.0)>,
#  (22, 23): <gurobi.Var x[22,23] (value -0.0)>,
#  (22, 24): <gurobi.Var x[22,24] (value -0.0)>,
#  (22, 25): <gurobi.Var x[22,25] (value -0.0)>,
#  (23, 24): <gurobi.Var x[23,24] (value -0.0)>,
#  (23, 25): <gurobi.Var x[23,25] (value -0.0)>,
#  (24, 25): <gurobi.Var x[24,25] (value -0.0)>}

# %%
x.sum(15,'*') + x.sum('*',15)
# Out:
# <gurobi.LinExpr: x[15,16] + x[15,17] + x[15,18] + x[15,19] + x[15,20] + x[15,21] + x[15,22] + x[15,23] + x[15,24] + x[15,25] + x[1,15] + x[2,15] + x[3,15] + x[4,15] + x[5,15] + x[6,15] + x[7,15] + x[8,15] + x[9,15] + x[10,15] + x[11,15] + x[12,15] + x[13,15] + x[14,15]>

# %%
for i in range(16,G.number_of_nodes()+1):
    print (x.sum(i,'*') + x.sum('*',i))
    print ()
# Out:
# <gurobi.LinExpr: x[16,17] + x[16,18] + x[16,19] + x[16,20] + x[16,21] + x[16,22] + x[16,23] + x[16,24] + x[16,25] + x[1,16] + x[2,16] + x[3,16] + x[4,16] + x[5,16] + x[6,16] + x[7,16] + x[8,16] + x[9,16] + x[10,16] + x[11,16] + x[12,16] + x[13,16] + x[14,16] + x[15,16]>
#
# <gurobi.LinExpr: x[17,18] + x[17,19] + x[17,20] + x[17,21] + x[17,22] + x[17,23] + x[17,24] + x[17,25] + x[1,17] + x[2,17] + x[3,17] + x[4,17] + x[5,17] + x[6,17] + x[7,17] + x[8,17] + x[9,17] + x[10,17] + x[11,17] + x[12,17] + x[13,17] + x[14,17] + x[15,17] + x[16,17]>
#
# <gurobi.LinExpr: x[18,19] + x[18,20] + x[18,21] + x[18,22] + x[18,23] + x[18,24] + x[18,25] + x[1,18] + x[2,18] + x[3,18] + x[4,18] + x[5,18] + x[6,18] + x[7,18] + x[8,18] + x[9,18] + x[10,18] + x[11,18] + x[12,18] + x[13,18] + x[14,18] + x[15,18] + x[16,18] + x[17,18]>
#
# <gurobi.LinExpr: x[19,20] + x[19,21] + x[19,22] + x[19,23] + x[19,24] + x[19,25] + x[1,19] + x[2,19] + x[3,19] + x[4,19] + x[5,19] + x[6,19] + x[7,19] + x[8,19] + x[9,19] + x[10,19] + x[11,19] + x[12,19] + x[13,19] + x[14,19] + x[15,19] + x[16,19] + x[17,19] + x[18,19]>
#
# <gurobi.LinExpr: x[20,21] + x[20,22] + x[20,23] + x[20,24] + x[20,25] + x[1,20] + x[2,20] + x[3,20] + x[4,20] + x[5,20] + x[6,20] + x[7,20] + x[8,20] + x[9,20] + x[10,20] + x[11,20] + x[12,20] + x[13,20] + x[14,20] + x[15,20] + x[16,20] + x[17,20] + x[18,20] + x[19,20]>
#
# <gurobi.LinExpr: x[21,22] + x[21,23] + x[21,24] + x[21,25] + x[1,21] + x[2,21] + x[3,21] + x[4,21] + x[5,21] + x[6,21] + x[7,21] + x[8,21] + x[9,21] + x[10,21] + x[11,21] + x[12,21] + x[13,21] + x[14,21] + x[15,21] + x[16,21] + x[17,21] + x[18,21] + x[19,21] + x[20,21]>
#
# <gurobi.LinExpr: x[22,23] + x[22,24] + x[22,25] + x[1,22] + x[2,22] + x[3,22] + x[4,22] + x[5,22] + x[6,22] + x[7,22] + x[8,22] + x[9,22] + x[10,22] + x[11,22] + x[12,22] + x[13,22] + x[14,22] + x[15,22] + x[16,22] + x[17,22] + x[18,22] + x[19,22] + x[20,22] + x[21,22]>
#
# <gurobi.LinExpr: x[23,24] + x[23,25] + x[1,23] + x[2,23] + x[3,23] + x[4,23] + x[5,23] + x[6,23] + x[7,23] + x[8,23] + x[9,23] + x[10,23] + x[11,23] + x[12,23] + x[13,23] + x[14,23] + x[15,23] + x[16,23] + x[17,23] + x[18,23] + x[19,23] + x[20,23] + x[21,23] + x[22,23]>
#
# <gurobi.LinExpr: x[24,25] + x[1,24] + x[2,24] + x[3,24] + x[4,24] + x[5,24] + x[6,24] + x[7,24] + x[8,24] + x[9,24] + x[10,24] + x[11,24] + x[12,24] + x[13,24] + x[14,24] + x[15,24] + x[16,24] + x[17,24] + x[18,24] + x[19,24] + x[20,24] + x[21,24] + x[22,24] + x[23,24]>
#
# <gurobi.LinExpr: x[1,25] + x[2,25] + x[3,25] + x[4,25] + x[5,25] + x[6,25] + x[7,25] + x[8,25] + x[9,25] + x[10,25] + x[11,25] + x[12,25] + x[13,25] + x[14,25] + x[15,25] + x[16,25] + x[17,25] + x[18,25] + x[19,25] + x[20,25] + x[21,25] + x[22,25] + x[23,25] + x[24,25]>

# %%
mst.reset()
mst.addConstrs((x.sum(i,'*') + x.sum('*',i) <= 2 \
                for i in range(16,G.number_of_nodes()+1)),\
               name='Degree')
# Out:
# {16: <gurobi.Constr *Awaiting Model Update*>,
#  17: <gurobi.Constr *Awaiting Model Update*>,
#  18: <gurobi.Constr *Awaiting Model Update*>,
#  19: <gurobi.Constr *Awaiting Model Update*>,
#  20: <gurobi.Constr *Awaiting Model Update*>,
#  21: <gurobi.Constr *Awaiting Model Update*>,
#  22: <gurobi.Constr *Awaiting Model Update*>,
#  23: <gurobi.Constr *Awaiting Model Update*>,
#  24: <gurobi.Constr *Awaiting Model Update*>,
#  25: <gurobi.Constr *Awaiting Model Update*>}

# %%
mst.Params.lazyConstraints = 1
mst.optimize(SECcallback)
# Out:
# Parameter lazyConstraints unchanged
#    Value: 1  Min: 0  Max: 1  Default: 0
# Optimize a model with 21 rows, 300 columns and 780 nonzeros
# Variable types: 0 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 8e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+01]
# Presolve removed 10 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 300 columns, 540 nonzeros
# Variable types: 0 continuous, 300 integer (300 binary)
#
# Root relaxation: objective 1.637500e+04, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 19413.0000    0    4          - 19413.0000      -     -    0s
#      0     2 19413.0000    0    4          - 19413.0000      -     -    0s
# *    6     2               1    19693.000000 19505.0000  0.95%   4.3    0s
#
# Cutting planes:
#   Lazy constraints: 23
#
# Explored 9 nodes (60 simplex iterations) in 0.08 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 19693
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.969300000000e+04, best bound 1.969300000000e+04, gap 0.0000%

# %%
DrawInitialGraph()
DrawSol(x)
display(SVG(filename=basename+'_sol.svg'))

# %%
scaledG = G.copy()

# %%
scaledG.edges(data=True)
# Out:
# EdgeDataView([(1, 2, {'cost': 3687, 'capacity': -0.0}), (1, 3, {'cost': 984, 'capacity': 1.0}), (1, 4, {'cost': 2765, 'capacity': -0.0}), (1, 5, {'cost': 4167, 'capacity': -0.0}), (1, 6, {'cost': 1581, 'capacity': -0.0}), (1, 7, {'cost': 3397, 'capacity': -0.0}), (1, 8, {'cost': 921, 'capacity': 1.000000000000019}), (1, 9, {'cost': 2607, 'capacity': -0.0}), (1, 10, {'cost': 2807, 'capacity': -0.0}), (1, 11, {'cost': 3622, 'capacity': -0.0}), (1, 12, {'cost': 1029, 'capacity': -0.0}), (1, 13, {'cost': 2137, 'capacity': -0.0}), (1, 14, {'cost': 500, 'capacity': 1.0}), (1, 15, {'cost': 1920, 'capacity': -0.0}), (1, 16, {'cost': 2765, 'capacity': -0.0}), (1, 17, {'cost': 2842, 'capacity': -0.0}), (1, 18, {'cost': 2059, 'capacity': -0.0}), (1, 19, {'cost': 2209, 'capacity': -0.0}), (1, 20, {'cost': 1529, 'capacity': -0.0}), (1, 21, {'cost': 1272, 'capacity': -0.0}), (1, 22, {'cost': 2954, 'capacity': -0.0}), (1, 23, {'cost': 2126, 'capacity': -0.0}), (1, 24, {'cost': 3828, 'capacity': -0.0}), (1, 25, {'cost': 4002, 'capacity': -0.0}), (2, 3, {'cost': 2830, 'capacity': -0.0}), (2, 4, {'cost': 4257, 'capacity': -0.0}), (2, 5, {'cost': 6040, 'capacity': -0.0}), (2, 6, {'cost': 3624, 'capacity': -0.0}), (2, 7, {'cost': 509, 'capacity': 1.0}), (2, 8, {'cost': 3661, 'capacity': -0.0}), (2, 9, {'cost': 1414, 'capacity': -0.0}), (2, 10, {'cost': 2200, 'capacity': 0.0}), (2, 11, {'cost': 6462, 'capacity': -0.0}), (2, 12, {'cost': 4701, 'capacity': -0.0}), (2, 13, {'cost': 2418, 'capacity': -0.0}), (2, 14, {'cost': 4186, 'capacity': -0.0}), (2, 15, {'cost': 3827, 'capacity': -0.0}), (2, 16, {'cost': 6129, 'capacity': -0.0}), (2, 17, {'cost': 4242, 'capacity': -0.0}), (2, 18, {'cost': 4569, 'capacity': -0.0}), (2, 19, {'cost': 3006, 'capacity': -0.0}), (2, 20, {'cost': 4632, 'capacity': -0.0}), (2, 21, {'cost': 3807, 'capacity': -0.0}), (2, 22, {'cost': 5345, 'capacity': -0.0}), (2, 23, {'cost': 4237, 'capacity': -0.0}), (2, 24, {'cost': 583, 'capacity': 0.0}), (2, 25, {'cost': 7306, 'capacity': -0.0}), (3, 4, {'cost': 3190, 'capacity': -0.0}), (3, 5, {'cost': 4810, 'capacity': -0.0}), (3, 6, {'cost': 2012, 'capacity': -0.0}), (3, 7, {'cost': 2483, 'capacity': -0.0}), (3, 8, {'cost': 1529, 'capacity': -0.0}), (3, 9, {'cost': 1640, 'capacity': 0.0}), (3, 10, {'cost': 2500, 'capacity': -0.0}), (3, 11, {'cost': 4500, 'capacity': -0.0}), (3, 12, {'cost': 1910, 'capacity': -0.0}), (3, 13, {'cost': 1200, 'capacity': 1.0}), (3, 14, {'cost': 1442, 'capacity': 0.0}), (3, 15, {'cost': 2370, 'capacity': -0.0}), (3, 16, {'cost': 3736, 'capacity': -0.0}), (3, 17, {'cost': 3244, 'capacity': -0.0}), (3, 18, {'cost': 2765, 'capacity': -0.0}), (3, 19, {'cost': 1431, 'capacity': -0.0}), (3, 20, {'cost': 2402, 'capacity': -0.0}), (3, 21, {'cost': 1868, 'capacity': -0.0}), (3, 22, {'cost': 3687, 'capacity': -0.0}), (3, 23, {'cost': 2692, 'capacity': -0.0}), (3, 24, {'cost': 2900, 'capacity': -0.0}), (3, 25, {'cost': 4972, 'capacity': -0.0}), (4, 5, {'cost': 1800, 'capacity': -0.0}), (4, 6, {'cost': 1204, 'capacity': -0.0}), (4, 7, {'cost': 4304, 'capacity': -0.0}), (4, 8, {'cost': 1843, 'capacity': -0.0}), (4, 9, {'cost': 4060, 'capacity': -0.0}), (4, 10, {'cost': 2118, 'capacity': -0.0}), (4, 11, {'cost': 2475, 'capacity': -0.0}), (4, 12, {'cost': 3269, 'capacity': -0.0}), (4, 13, {'cost': 4254, 'capacity': -0.0}), (4, 14, {'cost': 2915, 'capacity': -0.0}), (4, 15, {'cost': 848, 'capacity': 1.0}), (4, 16, {'cost': 2846, 'capacity': -0.0}), (4, 17, {'cost': 100, 'capacity': 1.0}), (4, 18, {'cost': 1100, 'capacity': -0.0}), (4, 19, {'cost': 4614, 'capacity': -0.0}), (4, 20, {'cost': 1824, 'capacity': -0.0}), (4, 21, {'cost': 1500, 'capacity': -0.0}), (4, 22, {'cost': 1272, 'capacity': -0.0}), (4, 23, {'cost': 728, 'capacity': 1.9984014443252818e-15}), (4, 24, {'cost': 4716, 'capacity': -0.0}), (4, 25, {'cost': 3661, 'capacity': -0.0}), (5, 6, {'cost': 2816, 'capacity': -0.0}), (5, 7, {'cost': 6103, 'capacity': -0.0}), (5, 8, {'cost': 3310, 'capacity': -0.0}), (5, ...

# %%
scaledG[21]
# Out:
# AtlasView({1: {'cost': 1272, 'capacity': -0.0}, 2: {'cost': 3807, 'capacity': -0.0}, 3: {'cost': 1868, 'capacity': -0.0}, 4: {'cost': 1500, 'capacity': -0.0}, 5: {'cost': 2954, 'capacity': -0.0}, 6: {'cost': 400, 'capacity': 1.0}, 7: {'cost': 3676, 'capacity': -0.0}, 8: {'cost': 360, 'capacity': 1.0}, 9: {'cost': 3140, 'capacity': -0.0}, 10: {'cost': 2195, 'capacity': -0.0}, 11: {'cost': 2745, 'capacity': -0.0}, 12: {'cost': 1843, 'capacity': -0.0}, 13: {'cost': 3041, 'capacity': -0.0}, 14: {'cost': 1431, 'capacity': -0.0}, 15: {'cost': 670, 'capacity': -0.0}, 16: {'cost': 2343, 'capacity': -0.0}, 17: {'cost': 1581, 'capacity': -0.0}, 18: {'cost': 905, 'capacity': -0.0}, 19: {'cost': 3289, 'capacity': -0.0}, 20: {'cost': 848, 'capacity': 0.0}, 22: {'cost': 1824, 'capacity': -0.0}, 23: {'cost': 860, 'capacity': -0.0}, 24: {'cost': 4123, 'capacity': -0.0}, 25: {'cost': 3498, 'capacity': -0.0}})

# %%
for i in scaledG[21]:
    scaledG[i][21]['cost'] /= 10

# %%
scaledG[21]
# Out:
# AtlasView({1: {'cost': 127.2, 'capacity': -0.0}, 2: {'cost': 380.7, 'capacity': -0.0}, 3: {'cost': 186.8, 'capacity': -0.0}, 4: {'cost': 150.0, 'capacity': -0.0}, 5: {'cost': 295.4, 'capacity': -0.0}, 6: {'cost': 40.0, 'capacity': 1.0}, 7: {'cost': 367.6, 'capacity': -0.0}, 8: {'cost': 36.0, 'capacity': 1.0}, 9: {'cost': 314.0, 'capacity': -0.0}, 10: {'cost': 219.5, 'capacity': -0.0}, 11: {'cost': 274.5, 'capacity': -0.0}, 12: {'cost': 184.3, 'capacity': -0.0}, 13: {'cost': 304.1, 'capacity': -0.0}, 14: {'cost': 143.1, 'capacity': -0.0}, 15: {'cost': 67.0, 'capacity': -0.0}, 16: {'cost': 234.3, 'capacity': -0.0}, 17: {'cost': 158.1, 'capacity': -0.0}, 18: {'cost': 90.5, 'capacity': -0.0}, 19: {'cost': 328.9, 'capacity': -0.0}, 20: {'cost': 84.8, 'capacity': 0.0}, 22: {'cost': 182.4, 'capacity': -0.0}, 23: {'cost': 86.0, 'capacity': -0.0}, 24: {'cost': 412.3, 'capacity': -0.0}, 25: {'cost': 349.8, 'capacity': -0.0}})

# %%
mst = gb.Model()

# Decision Variables

x = mst.addVars(scaledG.edges(),\
                obj=[scaledG[u][v]['cost'] for u,v in scaledG.edges()],\
                ub = 1.0,\
                vtype=gb.GRB.BINARY, name='x')

# Cardinality constraint

mst.addConstr(x.sum() == scaledG.number_of_nodes() - 1, 'Cardinality')

mst.update()

mst._graph = scaledG
mst._vars = x
mst._nSEC = 0



import math
import itertools

def SECcallback (model, where):

        
    if where == gb.GRB.Callback.MIPSOL:
        
        x = model._vars
        xrel = model.cbGetSolution(x)
        G = model._graph
        
        #
        # Make a graph working copy
        # Not efficient !!!
        #
        
        solG = nx.Graph([(u,v) for (u,v) in G.edges() \
                         if math.isclose(xrel[u,v], 1.0, abs_tol=1E-3)])

        #
        # Check if solG is connected
        #
        
        for cc in nx.connected_components(solG):
            if G.subgraph(cc).number_of_edges() > len(cc) - 1 and len(cc) > 2:
                seclhs = gb.quicksum(x[u,v] if (u,v) in x else x[v,u] \
                                 for u,v in itertools.combinations(cc, 2))
            
                model.cbLazy(seclhs <= len(cc) - 1)

# %%
mst.addConstr(x.sum(21,'*') + x.sum('*',21) <= 6, name='Degree')
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
                
mst.reset()
mst.Params.lazyConstraints = 1
mst.optimize(SECcallback)
# Out:
# Parameter lazyConstraints unchanged
#    Value: 1  Min: 0  Max: 1  Default: 0
# Optimize a model with 2 rows, 300 columns and 324 nonzeros
# Variable types: 0 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+01, 8e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [6e+00, 2e+01]
# Presolve time: 0.00s
# Presolved: 2 rows, 300 columns, 324 nonzeros
# Variable types: 0 continuous, 300 integer (300 binary)
#
# Root relaxation: objective 1.114830e+04, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 13083.9333    0    5          - 13083.9333      -     -    0s
#      0     2 13423.7667    0   12          - 13423.7667      -     -    0s
# *    7     1               1    13677.500000 13439.1000  1.74%   1.9    0s
# *   10     1               2    13457.800000 13457.8000  0.00%   1.8    0s
#
# Cutting planes:
#   Lazy constraints: 35
#
# Explored 11 nodes (36 simplex iterations) in 0.15 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 13457.8 13677.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.345780000000e+04, best bound 1.345780000000e+04, gap 0.0000%

# %%
DrawInitialGraph()
DrawSol(x)
display(SVG(filename=basename+'_sol.svg'))
